# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:/Users/anjan/Downloads/Employee.csv")
df
# Out:
#      Company   Age  Salary     Place Country  Gender
# 0        TCS  20.0     NaN   Chennai   India       0
# 1    Infosys  30.0     NaN    Mumbai   India       0
# 2        TCS  35.0  2300.0  Calcutta   India       0
# 3    Infosys  40.0  3000.0     Delhi   India       0
# 4        TCS  23.0  4000.0    Mumbai   India       0
# ..       ...   ...     ...       ...     ...     ...
# 143      TCS  33.0  9024.0  Calcutta   India       1
# 144  Infosys  22.0  8787.0  Calcutta   India       1
# 145  Infosys  44.0  4034.0     Delhi   India       1
# 146      TCS  33.0  5034.0    Mumbai   India       1
# 147  Infosys  22.0  8202.0    Cochin   India       0
#
# [148 rows x 6 columns]

# %% [markdown]
# # DATA EXPLORATION

# %%
df.describe()
# Out:
#               Age       Salary      Gender
# count  130.000000   124.000000  148.000000
# mean    30.484615  5312.467742    0.222973
# std     11.096640  2573.764683    0.417654
# min      0.000000  1089.000000    0.000000
# 25%     22.000000  3030.000000    0.000000
# 50%     32.500000  5000.000000    0.000000
# 75%     37.750000  8000.000000    0.000000
# max     54.000000  9876.000000    1.000000

# %%
df.head()
# Out:
#    Company   Age  Salary     Place Country  Gender
# 0      TCS  20.0     NaN   Chennai   India       0
# 1  Infosys  30.0     NaN    Mumbai   India       0
# 2      TCS  35.0  2300.0  Calcutta   India       0
# 3  Infosys  40.0  3000.0     Delhi   India       0
# 4      TCS  23.0  4000.0    Mumbai   India       0

# %%
df.isnull().sum()
# Out:
# Company     8
# Age        18
# Salary     24
# Place      14
# Country     0
# Gender      0
# dtype: int64

# %%
df.shape
# Out:
# (148, 6)

# %% [markdown]
# # DATA CLEANING

# %%
df1=df.drop(["Country", "Gender"], axis=1)
df1
# Out:
#      Company   Age  Salary     Place
# 0        TCS  20.0     NaN   Chennai
# 1    Infosys  30.0     NaN    Mumbai
# 2        TCS  35.0  2300.0  Calcutta
# 3    Infosys  40.0  3000.0     Delhi
# 4        TCS  23.0  4000.0    Mumbai
# ..       ...   ...     ...       ...
# 143      TCS  33.0  9024.0  Calcutta
# 144  Infosys  22.0  8787.0  Calcutta
# 145  Infosys  44.0  4034.0     Delhi
# 146      TCS  33.0  5034.0    Mumbai
# 147  Infosys  22.0  8202.0    Cochin
#
# [148 rows x 4 columns]

# %%
df1.rename(columns={'Place':'Location'}, inplace=True)
df1
# Out:
#      Company   Age  Salary  Location
# 0        TCS  20.0     NaN   Chennai
# 1    Infosys  30.0     NaN    Mumbai
# 2        TCS  35.0  2300.0  Calcutta
# 3    Infosys  40.0  3000.0     Delhi
# 4        TCS  23.0  4000.0    Mumbai
# ..       ...   ...     ...       ...
# 143      TCS  33.0  9024.0  Calcutta
# 144  Infosys  22.0  8787.0  Calcutta
# 145  Infosys  44.0  4034.0     Delhi
# 146      TCS  33.0  5034.0    Mumbai
# 147  Infosys  22.0  8202.0    Cochin
#
# [148 rows x 4 columns]

# %%
df2=df1.drop_duplicates()
df2
# Out:
#              Company   Age  Salary   Location
# 0                TCS  20.0     NaN    Chennai
# 1            Infosys  30.0     NaN     Mumbai
# 2                TCS  35.0  2300.0   Calcutta
# 3            Infosys  40.0  3000.0      Delhi
# 4                TCS  23.0  4000.0     Mumbai
# ..               ...   ...     ...        ...
# 139       Congnizant  22.0  2934.0      Noida
# 140          Infosys  44.0  4034.0  Hyderabad
# 141              TCS  33.0  5034.0   Calcutta
# 142  Infosys Pvt Lmt  22.0  8202.0     Mumbai
# 143              TCS  33.0  9024.0   Calcutta
#
# [140 rows x 4 columns]

# %%
df2.Age.mean()
# Out:
# 30.536585365853657

# %%
df_new=df2.fillna(df['Salary'].mean())
df_new
# Out:
#              Company   Age       Salary   Location
# 0                TCS  20.0  5312.467742    Chennai
# 1            Infosys  30.0  5312.467742     Mumbai
# 2                TCS  35.0  2300.000000   Calcutta
# 3            Infosys  40.0  3000.000000      Delhi
# 4                TCS  23.0  4000.000000     Mumbai
# ..               ...   ...          ...        ...
# 139       Congnizant  22.0  2934.000000      Noida
# 140          Infosys  44.0  4034.000000  Hyderabad
# 141              TCS  33.0  5034.000000   Calcutta
# 142  Infosys Pvt Lmt  22.0  8202.000000     Mumbai
# 143              TCS  33.0  9024.000000   Calcutta
#
# [140 rows x 4 columns]

# %%
df_new1=df_new.fillna(df['Age'].mean())
df_new1
# Out:
#              Company   Age       Salary   Location
# 0                TCS  20.0  5312.467742    Chennai
# 1            Infosys  30.0  5312.467742     Mumbai
# 2                TCS  35.0  2300.000000   Calcutta
# 3            Infosys  40.0  3000.000000      Delhi
# 4                TCS  23.0  4000.000000     Mumbai
# ..               ...   ...          ...        ...
# 139       Congnizant  22.0  2934.000000      Noida
# 140          Infosys  44.0  4034.000000  Hyderabad
# 141              TCS  33.0  5034.000000   Calcutta
# 142  Infosys Pvt Lmt  22.0  8202.000000     Mumbai
# 143              TCS  33.0  9024.000000   Calcutta
#
# [140 rows x 4 columns]

# %%
mean=df_new1.Salary.mean()
mean
# Out:
# 5253.069700460829

# %%
median=df_new1.Salary.median()
median
# Out:
# 5312.467741935484

# %%
std=df_new1.Salary.std()
std
# Out:
# 2368.2139747583583

# %%
mean+3*std
# Out:
# 12357.711624735904

# %%
mean-3*std
# Out:
# -1851.5722238142453

# %%
df_new1
# Out:
#              Company   Age       Salary   Location
# 0                TCS  20.0  5312.467742    Chennai
# 1            Infosys  30.0  5312.467742     Mumbai
# 2                TCS  35.0  2300.000000   Calcutta
# 3            Infosys  40.0  3000.000000      Delhi
# 4                TCS  23.0  4000.000000     Mumbai
# ..               ...   ...          ...        ...
# 139       Congnizant  22.0  2934.000000      Noida
# 140          Infosys  44.0  4034.000000  Hyderabad
# 141              TCS  33.0  5034.000000   Calcutta
# 142  Infosys Pvt Lmt  22.0  8202.000000     Mumbai
# 143              TCS  33.0  9024.000000   Calcutta
#
# [140 rows x 4 columns]

# %%
df[(df.Salary>-1851) & (df.Salary<12357)]
# Out:
#      Company   Age  Salary     Place Country  Gender
# 2        TCS  35.0  2300.0  Calcutta   India       0
# 3    Infosys  40.0  3000.0     Delhi   India       0
# 4        TCS  23.0  4000.0    Mumbai   India       0
# 5    Infosys   NaN  5000.0  Calcutta   India       0
# 6        TCS   NaN  6000.0   Chennai   India       1
# ..       ...   ...     ...       ...     ...     ...
# 143      TCS  33.0  9024.0  Calcutta   India       1
# 144  Infosys  22.0  8787.0  Calcutta   India       1
# 145  Infosys  44.0  4034.0     Delhi   India       1
# 146      TCS  33.0  5034.0    Mumbai   India       1
# 147  Infosys  22.0  8202.0    Cochin   India       0
#
# [124 rows x 6 columns]

# %% [markdown]
# # DATA ANALYSIS

# %%
age_salary_plot = df_new1[(df_new1.Age > 40) & (df_new1.Salary < 5000)]
age_salary_plot
# Out:
#          Company          Age  Salary   Location
# 21       Infosys    50.000000  3184.0      Delhi
# 32       Infosys    45.000000  4034.0   Calcutta
# 39       Infosys    41.000000  3000.0     Mumbai
# 50       Infosys    41.000000  3000.0    Chennai
# 57       Infosys    51.000000  3184.0  Hyderabad
# 68       Infosys    43.000000  4034.0     Mumbai
# 75       Infosys    44.000000  3000.0     Cochin
# 86       Infosys    41.000000  3000.0      Delhi
# 93       Infosys    54.000000  3184.0     Mumbai
# 104      Infosys    44.000000  4034.0      Delhi
# 122      Infosys    44.000000  3234.0     Mumbai
# 123  5312.467742  5312.467742  3454.0   Calcutta
# 129      Infosys    50.000000  3184.0   Calcutta
# 138          CTS    44.000000  3033.0     Cochin
# 140      Infosys    44.000000  4034.0  Hyderabad

# %%
import seaborn as sns
sns.scatterplot(data=age_salary_plot, x= 'Age', y='Salary')
plt.figure(figsize=(8,6))

# %%
count=age_salary_plot.value_counts('Location')
count
# Out:
# Location
# Mumbai       4
# Calcutta     3
# Delhi        3
# Cochin       2
# Hyderabad    2
# Chennai      1
# Name: count, dtype: int64

# %%
sns.barplot(x=count.index, y= count.values)
# Out:
# <Axes: xlabel='Location'>

# %% [markdown]
# # DATA ENCODING

# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder
# Out:
#   Cell In[64], line 2
#     from sklearn.preprocessing
#                               ^
# SyntaxError: invalid syntax
